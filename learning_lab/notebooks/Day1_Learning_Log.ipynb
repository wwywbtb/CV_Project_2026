# %%
# 单元格 1：测试环境和基础语法
print("🎯 Day 1 学习日志 - Jupyter 测试")
print("当前环境：cv_2026")

import sys
print(f"Python 版本: {sys.version}")

# 测试今天学过的包
try:
    import cv2
    print(f"✅ OpenCV 版本: {cv2.__version__}")
except ImportError:
    print("❌ OpenCV 未安装")

import numpy as np
print(f"✅ NumPy 版本: {np.__version__}")
# Out:
# 🎯 Day 1 学习日志 - Jupyter 测试
# 当前环境：cv_2026
# Python 版本: 3.9.25 (main, Nov  3 2025, 22:44:01) [MSC v.1929 64 bit (AMD64)]
# ❌ OpenCV 未安装
# ✅ NumPy 版本: 2.0.1

# %%
# 单元格 2：交互式 Python 语法练习（补课核心）
# 1. 列表与循环 - 模拟处理图像像素
print("=== 像素值处理练习 ===")
pixel_batch = [45, 120, 255, 80, 160]
print(f"原始像素值: {pixel_batch}")

# 使用列表推导式进行“二值化”
threshold = 128
binary_pixels = [1 if p > threshold else 0 for p in pixel_batch]
print(f"二值化后 (阈值{threshold}): {binary_pixels}")
# Out:
# === 像素值处理练习 ===
# 原始像素值: [45, 120, 255, 80, 160]
# 二值化后 (阈值128): [0, 0, 1, 0, 1]
