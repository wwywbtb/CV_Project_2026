# %%
a=1 
b=3.14
c=1+2j
print(a)
print(b)
print(c)
# Out:
# 1
# 3.14
# (1+2j)

# %%
print(1+2)
# Out:
# 3

# %%
b=3.13
print(b)
b = int(b)
print(b)
# Out:
# 3.13
# 3

# %%
>>> 5 ** 2
# Out:
# 25

# %%
>>> 3 + 2
# Out:
# 5

# %%
>>> 3 - 2
# Out:
# 1

# %%
>>> 5 * 2
# Out:
# 10

# %%
>>> 5 / 2
# Out:
# 2.5

# %%
>>> 5 // 2
# Out:
# 2

# %%
>>> 5 % 2
# Out:
# 1

# %%
>>> 2 ** 5
# Out:
# 32

# %%
>>> 3 / -1
# Out:
# -3.0

# %%
>>> 3 - 5
# Out:
# -2

# %%
print(1==2)
# Out:
# False

# %%
print(1!=2)
# Out:
# True

# %%
print(3>=2)
# Out:
# True

# %%
print(3>2)
# Out:
# True

# %%
print(1 and 2)
# Out:
# 2

# %%
print(1 and 0)
# Out:
# 0

# %%
print(2 and 0)
# Out:
# 0

# %%
print(1 or 0)
# Out:
# 1

# %%
print(not 0)
# Out:
# True

# %%
print(not 1)
# Out:
# False

# %%
a=3
print(a)
a=5
print(a)
# Out:
# 3
# 5

# %%
str = 'WWenuyyubo'
print(str)
print(str[0])
print(str[-1])
print("%s,sdk%d" % (str,32))
print(str[1::2])
print(str[::2])
print(str[-1::])
print(str[::-1])
print(str.lower())
print(str.upper())
print(str.islower())
print(str.isupper())
print(str.isdigit())
print(str.find('e'))
print(str.split('e'))
print(str.replace('e','E'))
str.replace('e','E')
print(str)
str1 = str.replace('e','E')
print(str1)
# Out:
# WWenuyyubo
# W
# o
# WWenuyyubo,sdk32
# Wnyuo
# Weuyb
# o
# obuyyuneWW
# wwenuyyubo
# WWENUYYUBO
# False
# False
# False
# 2
# ['WW', 'nuyyubo']
# WWEnuyyubo
# WWenuyyubo
# WWEnuyyubo

# %%
list1 = [1,'ac',4.3,[3,3]]
list2 = [2,'a',list1]
print(list1)
print(list1[1][1])
print(list1[0:3])
list1[0] = 3
print(list1)
list1.append('333')
print(list1)
list1.insert(1,23)
print(list1)
list1.pop()
print(list1)
list1.remove(3)
print(list1)
list1.clear()
print(list1)

list1.append(222)
print(list1)
print(list2)

list1[0]=66
print(list1)
print(list2)

list1=[2,4,6]
print(list1)
print(list2)
# Out:
# [1, 'ac', 4.3, [3, 3]]
# c
# [1, 'ac', 4.3]
# [3, 'ac', 4.3, [3, 3]]
# [3, 'ac', 4.3, [3, 3], '333']
# [3, 23, 'ac', 4.3, [3, 3], '333']
# [3, 23, 'ac', 4.3, [3, 3]]
# [23, 'ac', 4.3, [3, 3]]
# []
# [222]
# [2, 'a', [222]]
# [66]
# [2, 'a', [66]]
# [2, 4, 6]
# [2, 'a', [66]]
